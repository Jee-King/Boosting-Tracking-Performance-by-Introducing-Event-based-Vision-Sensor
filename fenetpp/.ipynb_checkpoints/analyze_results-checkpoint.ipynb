# %% [markdown]
# # Generating Results on Datasets

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import os
import sys
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [14, 8]

sys.path.append('../..')
from pytracking.analysis.plot_results import plot_results, print_results, print_per_sequence_results
from pytracking.evaluation import Tracker, get_dataset, trackerlist,  get_traindataset, get_valdataset

# %%
data_path = '/data/zjq/img_ext'
output_result = '/home/iccd/Document/Documents/pytracking/pytracking/tracking_results'
tracker_name = 'dimp'
test_case = 'prdimp18'
out_path = os.path.join(output_result,tracker_name,test_case)

# %% [markdown]
# ## Plots for OTB, NFS and UAV

# %%
trackers = []
# trackers.extend(trackerlist('dimp', 'prdimp18', None, 'prdimp18_20'))
# trackers.extend(trackerlist('atom', 'default', None, 'ATOM50'))
# trackers.extend(trackerlist('atom', 'attenv1', None, 'ATOMv1'))
# trackers.extend(trackerlist('atom', 'default_30epoch', None, 'ATOM30'))
# trackers.extend(trackerlist('atom', 'default_20epoch', None, 'ATOM20'))
# trackers.extend(trackerlist('dimp', 'prdimp18_epoch17', None, 'prdimp18_epoch17'))

trackers.extend(trackerlist('dimp', 'prdimp18_20', None, '20'))
trackers.extend(trackerlist('dimp', 'prdimp18_50', None, '50'))
trackers.extend(trackerlist('dimp', 'prdimp18', None, 'test_20'))

# trackers.extend(trackerlist('dimp', 'prdimp18', None, 'prdimp18_epoch30'))

# trackers.extend(trackerlist('dimp', 'prdimp18_attenv2', None, 'prdimp18_attenv2'))

dataset = get_valdataset('eotb')
plot_results(trackers, dataset, 'EOTB', merge_results=True, plot_types=('success', 'prec'), 
             skip_missing_seq=True, force_evaluation=True, plot_bin_gap=0.05, exclude_invalid_frames=False)
# Out:
# 100%|██████████| 32/32 [00:00<00:00, 38.75it/s]
# Computed results over 32 / 32 sequences
#
# Plotting results over 32 / 32 sequences
#
# Generating plots for: EOTB

# %% [markdown]
# ## Plots for LaSOT

# %%
trackers = []
trackers.extend(trackerlist('atom', 'default', range(0,5), 'ATOM'))
trackers.extend(trackerlist('dimp', 'dimp18', range(0,5), 'DiMP18'))
trackers.extend(trackerlist('dimp', 'dimp50', range(0,5), 'DiMP50'))
trackers.extend(trackerlist('dimp', 'prdimp18', range(0,5), 'PrDiMP18'))
trackers.extend(trackerlist('dimp', 'prdimp50', range(0,5), 'PrDiMP50'))

dataset = get_dataset('lasot')
plot_results(trackers, dataset, 'LaSOT', merge_results=True, plot_types=('success'), 
             skip_missing_seq=False, force_evaluation=True, plot_bin_gap=0.05)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-4-6b94306ca9ce> in <module>
#       6 trackers.extend(trackerlist('dimp', 'prdimp50', range(0,5), 'PrDiMP50'))
#       7
# ----> 8 dataset = get_dataset('lasot')
#       9 plot_results(trackers, dataset, 'LaSOT', merge_results=True, plot_types=('success'),
#      10              skip_missing_seq=False, force_evaluation=True, plot_bin_gap=0.05)
#
# ~/Document/Documents/pytracking/pytracking/evaluation/datasets.py in get_dataset(*args)
#      63     dset = SequenceList()
#      64     for name in args:
# ---> 65         dset.extend(load_dataset(name))
#      66     return dset
#      67
#
# ~/Document/Documents/pytracking/pytracking/evaluation/datasets.py in load_dataset(name, splits)
#      52     m = importlib.import_module(dset_info.module)
#      53     dataset = getattr(m, dset_info.class_name)(**dset_info.kwargs)  # Call the constructor
# ---> 54     sequence_list = dataset.get_sequence_list()
#      55     if splits is not None:
#      56         train_list = [f.strip() for f in open('../eotb_'+splits+'_split.txt', 'r').readlines()]
#
# ~/Document/Documents/pytracking/pytracking/evaluation/lasotdataset.py in get_sequence_list(self)
#      30
#      31     def get_sequence_list(self):
# ---> 32         return SequenceList([self._construct_sequence(s) for s in self.sequence_list])
#      33
#      34     def _construct_sequence(self, sequence_name):
#
# ~/Document/Documents/pytracking/pytracking/evaluation/lasotdataset.py in <listcomp>(.0)
#      30
#      31     def get_sequence_list(self):
# ---> 32         return SequenceList([self._construct_sequence(s) for s in self.sequence_list])
#      33
#      34     def _construct_sequence(self, sequence_name):
#
# ~/Document/Documents/pytracking/pytracking/evaluation/lasotdataset.py in _construct_sequence(self, sequence_name)
#      36         anno_path = '{}/{}/{}/groundtruth.txt'.format(self.base_path, class_name, sequence_name)
#      37
# ---> 38         ground_truth_rect = load_text(str(anno_path), delimiter=',', dtype=np.float64)
#      39
#      40         occlusion_label_path = '{}/{}/{}/full_occlusion.txt'.format(self.base_path, class_name, sequence_name)
#
# ~/Document/Documents/pytracking/pytracking/utils/load_text.py in load_text(path, delimiter, dtype, backend)
#      37 def load_text(path, delimiter=' ', dtype=np.float32, backend='numpy'):
#      38     if backend == 'numpy':
# ---> 39         return load_text_numpy(path, delimiter, dtype)
#      40     elif backend == 'pandas':
#      41         return load_text_pandas(path, delimiter, dtype)
#
# ~/Document/Documents/pytracking/pytracking/utils/load_text.py in load_text_numpy(path, delimiter, dtype)
#      14         raise Exception('Could not read file {}'.format(path))
#      15     else:
# ---> 16         ground_truth_rect = np.loadtxt(path, delimiter=delimiter, dtype=dtype)
#      17         return ground_truth_rect
#      18
#
# ~/miniconda3/envs/pytracking/lib/python3.8/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#     959             fname = os_fspath(fname)
#     960         if _is_string_like(fname):
# --> 961             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     962             fencoding = getattr(fh, 'encoding', 'latin1')
#     963             fh = iter(fh)
#
# ~/miniconda3/envs/pytracking/lib/python3.8/site-packages/numpy/lib/_datasource.py in open(path, mode, destpath, encoding, newline)
#     193
#     194     ds = DataSource(destpath)
# --> 195     return ds.open(path, mode, encoding=encoding, newline=newline)
#     196
#     197
#
# ~/miniconda3/envs/pytracking/lib/python3.8/site-packages/numpy/lib/_datasource.py in open(self, path, mode, encoding, newline)
#     533                                       encoding=encoding, newline=newline)
#     534         else:
# --> 535             raise IOError("%s not found." % path)
#     536
#     537
#
# OSError: /airplane/airplane-1/groundtruth.txt not found.

# %% [markdown]
# ## Tables for OTB, NFS, UAV and LaSOT

# %%
trackers = []
trackers.extend(trackerlist('atom', 'default', None, 'ATOM'))
# trackers.extend(trackerlist('dimp', 'dimp18', range(0,5), 'DiMP18'))
trackers.extend(trackerlist('dimp', 'dimp50', None, 'DiMP50'))
# trackers.extend(trackerlist('dimp', 'prdimp18', range(0,5), 'PrDiMP18'))
# trackers.extend(trackerlist('dimp', 'prdimp50', range(0,5), 'PrDiMP50'))

dataset = get_dataset('eotb')
print_results(trackers, dataset, 'OTB', merge_results=True, plot_types=('success', 'prec', 'norm_prec'))
# Out:
# 100%|██████████| 104/104 [00:07<00:00, 14.46it/s]
# Computed results over 104 / 104 sequences
#
# Reporting results over 104 / 104 sequences
#
# OTB         | AUC        | OP50       | OP75       | Precision    | Norm Precision    |
# ATOM        | 33.84      | 38.97      | 15.16      | 51.41        | 37.29             |
# DiMP50      | 43.47      | 52.20      | 19.25      | 64.67        | 48.31             |

# %% [markdown]
# ## Filtered per-sequence results

# %%
# Print per sequence results for sequences where all trackers fail, i.e. all trackers have average overlap in percentage of less than 10.0
filter_criteria = {'mode': 'ao_max', 'threshold': 100.0}
dataset = get_valdataset('eotb')
print_per_sequence_results(trackers, dataset, 'EOTB', merge_results=True, filter_criteria=filter_criteria, force_evaluation=False)
# Out:
#   0%|          | 0/32 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-5-83a8ea81f6b2> in <module>
#       2 filter_criteria = {'mode': 'ao_max', 'threshold': 100.0}
#       3 dataset = get_valdataset('eotb')
# ----> 4 print_per_sequence_results(trackers, dataset, 'EOTB', merge_results=True, filter_criteria=filter_criteria, force_evaluation=False)
#
# ~/Document/Documents/pytracking/pytracking/analysis/plot_results.py in print_per_sequence_results(trackers, dataset, report_name, merge_results, filter_criteria, **kwargs)
#     447     """
#     448     # Load pre-computed results
# --> 449     eval_data = check_and_load_precomputed_results(trackers, dataset, report_name, **kwargs)
#     450
#     451     # Merge results from multiple runs
#
# ~/Document/Documents/pytracking/pytracking/analysis/plot_results.py in check_and_load_precomputed_results(trackers, dataset, report_name, force_evaluation, **kwargs)
#     175     if not check_eval_data_is_valid(eval_data, trackers, dataset):
#     176         # print('Pre-computed evaluation data invalid. Re-computing results!')
# --> 177         eval_data = extract_results(trackers, dataset, report_name, **kwargs)
#     178     else:
#     179         # Update display names
#
# ~/Document/Documents/pytracking/pytracking/analysis/extract_results.py in extract_results(trackers, dataset, report_name, skip_missing_seq, plot_bin_gap, exclude_invalid_frames)
#     141                     break
#     142                 else:
# --> 143                     raise Exception('Result not found. {}'.format(results_path))
#     144
#     145             # Calculate measures
#
# Exception: Result not found. /home/iccd/Document/Documents/pytracking/pytracking/tracking_results//atom/default_000/tower.txt

# %%
# Print per sequence results for sequences where at least one tracker fails, i.e. a tracker has average overlap in percentage of less than 10.0
filter_criteria = {'mode': 'ao_min', 'threshold': 99.0}
dataset = get_dataset('eotb')
print_per_sequence_results(trackers, dataset, 'OTB+NFS+UAV', merge_results=True, filter_criteria=filter_criteria, force_evaluation=False)
# Out:
#                              | ATOM       |
# bottle_sim (ID=0)            | 68.86      |
# cow_high (ID=1)              | 85.10      |
# ship_low (ID=2)              | 6.29       |
# truck_hdr (ID=3)             | 9.54       |
# cup_low (ID=4)               | 7.14       |
# giraffe_hdr (ID=5)           | 3.39       |
# whale_low (ID=6)             | 39.70      |
# toy_car_low (ID=7)           | 65.55      |
# giraffe2 (ID=8)              | 61.51      |
# dog3 (ID=9)                  | 71.55      |
# ball_motion (ID=10)          | 11.45      |
# elephant_motion (ID=11)      | 63.30      |
# fighter3 (ID=12)             | 36.14      |

# %%
# Print per sequence results for sequences where the trackers have differing behavior.
# i.e. average overlap in percentage for different trackers on a sequence differ by at least 40.0
filter_criteria = {'mode': 'delta_ao', 'threshold': 40.0}
dataset = get_dataset('otb', 'nfs', 'uav')
print_per_sequence_results(trackers, dataset, 'OTB+NFS+UAV', merge_results=True, filter_criteria=filter_criteria, force_evaluation=False)

# %%
# Print per sequence results for all sequences
filter_criteria = None
dataset = get_dataset('eotb')
print_per_sequence_results(trackers, dataset, 'OTB+NFS+UAV', merge_results=False, filter_criteria=filter_criteria, force_evaluation=False)
# Out:
#                              | ATOM       |
# bottle_sim (ID=0)            | 68.86      |
# cow_high (ID=1)              | 85.10      |
# ship_low (ID=2)              | 6.29       |
# truck_hdr (ID=3)             | 9.54       |
# cup_low (ID=4)               | 7.14       |
# giraffe_hdr (ID=5)           | 3.39       |
# whale_low (ID=6)             | 39.70      |
# toy_car_low (ID=7)           | 65.55      |
# giraffe2 (ID=8)              | 61.51      |
# dog3 (ID=9)                  | 71.55      |
# ball_motion (ID=10)          | 11.45      |
# elephant_motion (ID=11)      | 63.30      |
# fighter3 (ID=12)             | 36.14      |
