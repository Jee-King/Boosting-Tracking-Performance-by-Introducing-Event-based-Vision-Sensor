# %% [markdown]
# # Generating Results on Datasets

# %%
import sys

sys.executable
import os
import cv2
import numpy as np
from PIL import Image, ImageDraw
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import sys
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [14, 8]

sys.path.append('../..')
from pytracking.analysis.plot_results import plot_results, print_results, print_per_sequence_results
from pytracking.evaluation import Tracker, get_dataset, trackerlist
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-0c3232815942> in <module>
#       1 import sys
#       2 import os
# ----> 3 import cv2
#       4 import numpy as np
#       5 from PIL import Image, ImageDraw
#
# ImportError: No module named 'cv2'

# %%
import matplotlib.pyplot as plt

# %%
data_path = '/data/zjq/img_ext'
output_result = '/home/zjq/Documents/pytracking/pytracking/tracking_results'
tracker_name = 'atom'
test_case = 'default'
out_path = os.path.join(output_result,tracker_name,test_case)

# %%
len_path = len(os.listdir(data_path))-len([i for i in os.listdir(data_path) if os.path.isdir(os.path.join(data_path,i))])

black_list = ["bottle_sim"]
white_list = ["bike_low"]
for index,filename in enumerate(os.listdir(data_path),1):
    if os.path.isdir(os.path.join(data_path,filename)):
        for file_name in white_list:
            print("Rendering {} {}/{}".format(file_name,index,len_path))
            i = 0
            bb_gt = np.rint(np.loadtxt(os.path.join(data_path,file_name,'groundtruth_rect.txt'),delimiter=','))
            bb_pre = np.rint(np.loadtxt(os.path.join(out_path,file_name+'.txt'),delimiter='\t'))
            root = os.path.join(data_path,file_name,'img')
            for f in sorted(os.listdir(os.path.join(data_path,file_name,'img'))):
                bb_gti = bb_gt[i]
                bb_prei = bb_pre[i]
                img_path = os.path.join(root,f)
                print(img_path)
                img = cv2.imread(img_path)
                img = cv2.rectangle(img,(int(bb_gti[0]), int(bb_gti[1])), (int(bb_gti[2] + bb_gti[0]), int(bb_gti[3] + bb_gti[1])),
                                           (0, 0, 255),1)
                img = cv2.rectangle(img,(int(bb_prei[0]), int(bb_prei[1])), (int(bb_prei[2] + bb_prei[0]), int(bb_prei[3] + bb_prei[1])),
                                           (255, 0, 255),1)
                image = Image.fromarray(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
                fig = plt.figure(figsize=(10, 5))
                plt.imshow(image), plt.axis('off')
                plt.show()
                i+=1
            break
# Out:
# Rendering bike_low 1/0
# /data/zjq/img_ext/bike_low/img/0001.jpg
# /data/zjq/img_ext/bike_low/img/0002.jpg
# /data/zjq/img_ext/bike_low/img/0003.jpg
# /data/zjq/img_ext/bike_low/img/0004.jpg
# /data/zjq/img_ext/bike_low/img/0005.jpg
# /data/zjq/img_ext/bike_low/img/0006.jpg
# /data/zjq/img_ext/bike_low/img/0007.jpg
# /data/zjq/img_ext/bike_low/img/0008.jpg
# /data/zjq/img_ext/bike_low/img/0009.jpg
# /data/zjq/img_ext/bike_low/img/0010.jpg
# /data/zjq/img_ext/bike_low/img/0011.jpg
# /data/zjq/img_ext/bike_low/img/0012.jpg
# /data/zjq/img_ext/bike_low/img/0013.jpg
# /data/zjq/img_ext/bike_low/img/0014.jpg
# /data/zjq/img_ext/bike_low/img/0015.jpg
# /data/zjq/img_ext/bike_low/img/0016.jpg
# /data/zjq/img_ext/bike_low/img/0017.jpg
# /data/zjq/img_ext/bike_low/img/0018.jpg
# /data/zjq/img_ext/bike_low/img/0019.jpg
# /data/zjq/img_ext/bike_low/img/0020.jpg
# /data/zjq/img_ext/bike_low/img/0021.jpg
# /data/zjq/img_ext/bike_low/img/0022.jpg
# /data/zjq/img_ext/bike_low/img/0023.jpg
# /data/zjq/img_ext/bike_low/img/0024.jpg
# /data/zjq/img_ext/bike_low/img/0025.jpg
# /data/zjq/img_ext/bike_low/img/0026.jpg
# /data/zjq/img_ext/bike_low/img/0027.jpg
# /data/zjq/img_ext/bike_low/img/0028.jpg
# /data/zjq/img_ext/bike_low/img/0029.jpg
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-521d1485ff43> in <module>
#      29                 image = Image.fromarray(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
#      30                 fig = plt.figure(figsize=(10, 5))
# ---> 31                 plt.imshow(image), plt.axis('off')
#      32                 plt.show()
#      33                 i+=1
#
# ~/miniconda3/envs/pytracking_vision/lib/python3.8/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, data, **kwargs)
#    2706         filternorm=True, filterrad=4.0, resample=None, url=None,
#    2707         data=None, **kwargs):
# -> 2708     __ret = gca().imshow(
#    2709         X, cmap=cmap, norm=norm, aspect=aspect,
#    2710         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# ~/miniconda3/envs/pytracking_vision/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# -> 1438             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1439
#    1440         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/miniconda3/envs/pytracking_vision/lib/python3.8/site-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, **kwargs)
#    5521                               resample=resample, **kwargs)
#    5522
# -> 5523         im.set_data(X)
#    5524         im.set_alpha(alpha)
#    5525         if im.get_clip_path() is None:
#
# ~/miniconda3/envs/pytracking_vision/lib/python3.8/site-packages/matplotlib/image.py in set_data(self, A)
#     694         if (self._A.dtype != np.uint8 and
#     695                 not np.can_cast(self._A.dtype, float, "same_kind")):
# --> 696             raise TypeError("Image data of dtype {} cannot be converted to "
#     697                             "float".format(self._A.dtype))
#     698
#
# TypeError: Image data of dtype object cannot be converted to float

# %% [markdown]
# ## Plots for OTB, NFS and UAV

# %%
trackers = []
trackers.extend(trackerlist('atom', 'default', None, 'ATOM'))
# trackers.extend(trackerlist('dimp', 'dimp50', None, 'DIMP'))
# trackers.extend(trackerlist('dimp', 'prdimp50', None, 'PrDIMP50'))

dataset = get_dataset('eotb')
plot_results(trackers, dataset, 'EOTB', merge_results=True, plot_types=('success', 'prec'), 
             skip_missing_seq=True, force_evaluation=True, plot_bin_gap=0.05, exclude_invalid_frames=False)
# Out:
# 100%|██████████| 102/102 [00:00<00:00, 408.65it/s]
# Computed results over 6 / 102 sequences
#
# Plotting results over 6 / 102 sequences
#
# Generating plots for: EOTB

# %% [markdown]
# ## Plots for LaSOT

# %%
trackers = []
trackers.extend(trackerlist('atom', 'default', range(0,5), 'ATOM'))
trackers.extend(trackerlist('dimp', 'dimp18', range(0,5), 'DiMP18'))
trackers.extend(trackerlist('dimp', 'dimp50', range(0,5), 'DiMP50'))
trackers.extend(trackerlist('dimp', 'prdimp18', range(0,5), 'PrDiMP18'))
trackers.extend(trackerlist('dimp', 'prdimp50', range(0,5), 'PrDiMP50'))

dataset = get_dataset('lasot')
plot_results(trackers, dataset, 'LaSOT', merge_results=True, plot_types=('success'), 
             skip_missing_seq=False, force_evaluation=True, plot_bin_gap=0.05)

# %% [markdown]
# ## Tables for OTB, NFS, UAV and LaSOT

# %%
trackers = []
trackers.extend(trackerlist('atom', 'default', None, 'ATOM'))
# trackers.extend(trackerlist('dimp', 'dimp18', range(0,5), 'DiMP18'))
trackers.extend(trackerlist('dimp', 'dimp50', None, 'DiMP50'))
# trackers.extend(trackerlist('dimp', 'prdimp18', range(0,5), 'PrDiMP18'))
# trackers.extend(trackerlist('dimp', 'prdimp50', range(0,5), 'PrDiMP50'))

dataset = get_dataset('eotb')
print_results(trackers, dataset, 'OTB', merge_results=True, plot_types=('success', 'prec', 'norm_prec'))
# Out:
# 100%|██████████| 104/104 [00:07<00:00, 14.46it/s]
# Computed results over 104 / 104 sequences
#
# Reporting results over 104 / 104 sequences
#
# OTB         | AUC        | OP50       | OP75       | Precision    | Norm Precision    |
# ATOM        | 33.84      | 38.97      | 15.16      | 51.41        | 37.29             |
# DiMP50      | 43.47      | 52.20      | 19.25      | 64.67        | 48.31             |

# %% [markdown]
# ## Filtered per-sequence results

# %%
# Print per sequence results for sequences where all trackers fail, i.e. all trackers have average overlap in percentage of less than 10.0
filter_criteria = {'mode': 'ao_max', 'threshold': 100.0}
dataset = get_dataset('eotb',)
print_per_sequence_results(trackers, dataset, 'EOTB', merge_results=True, filter_criteria=filter_criteria, force_evaluation=False)
# Out:
#                           | ATOM       |
# bottle_sim (ID=0)         | 75.65      |
# cup_low (ID=7)            | 61.96      |
# bottle (ID=14)            | 54.19      |
# fighter3 (ID=15)          | 63.01      |
# airplane_low (ID=21)      | 62.46      |
# bear_motion (ID=97)       | 3.47       |

# %%
# Print per sequence results for sequences where at least one tracker fails, i.e. a tracker has average overlap in percentage of less than 10.0
filter_criteria = {'mode': 'ao_min', 'threshold': 99.0}
dataset = get_dataset('eotb')
print_per_sequence_results(trackers, dataset, 'OTB+NFS+UAV', merge_results=True, filter_criteria=filter_criteria, force_evaluation=False)
# Out:
#                              | ATOM       |
# bottle_sim (ID=0)            | 68.86      |
# cow_high (ID=1)              | 85.10      |
# ship_low (ID=2)              | 6.29       |
# truck_hdr (ID=3)             | 9.54       |
# cup_low (ID=4)               | 7.14       |
# giraffe_hdr (ID=5)           | 3.39       |
# whale_low (ID=6)             | 39.70      |
# toy_car_low (ID=7)           | 65.55      |
# giraffe2 (ID=8)              | 61.51      |
# dog3 (ID=9)                  | 71.55      |
# ball_motion (ID=10)          | 11.45      |
# elephant_motion (ID=11)      | 63.30      |
# fighter3 (ID=12)             | 36.14      |

# %%
# Print per sequence results for sequences where the trackers have differing behavior.
# i.e. average overlap in percentage for different trackers on a sequence differ by at least 40.0
filter_criteria = {'mode': 'delta_ao', 'threshold': 40.0}
dataset = get_dataset('otb', 'nfs', 'uav')
print_per_sequence_results(trackers, dataset, 'OTB+NFS+UAV', merge_results=True, filter_criteria=filter_criteria, force_evaluation=False)

# %%
# Print per sequence results for all sequences
filter_criteria = None
dataset = get_dataset('eotb')
print_per_sequence_results(trackers, dataset, 'OTB+NFS+UAV', merge_results=False, filter_criteria=filter_criteria, force_evaluation=False)
# Out:
#  10%|▉         | 10/102 [00:02<00:25,  3.59it/s]
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-4-3d1244ede903> in <module>
#       2 filter_criteria = None
#       3 dataset = get_dataset('eotb')
# ----> 4 print_per_sequence_results(trackers, dataset, 'OTB+NFS+UAV', merge_results=False, filter_criteria=filter_criteria, force_evaluation=False)
#
# ~/Documents/pytracking/pytracking/analysis/plot_results.py in print_per_sequence_results(trackers, dataset, report_name, merge_results, filter_criteria, **kwargs)
#     447     """
#     448     # Load pre-computed results
# --> 449     eval_data = check_and_load_precomputed_results(trackers, dataset, report_name, **kwargs)
#     450
#     451     # Merge results from multiple runs
#
# ~/Documents/pytracking/pytracking/analysis/plot_results.py in check_and_load_precomputed_results(trackers, dataset, report_name, force_evaluation, **kwargs)
#     175     if not check_eval_data_is_valid(eval_data, trackers, dataset):
#     176         # print('Pre-computed evaluation data invalid. Re-computing results!')
# --> 177         eval_data = extract_results(trackers, dataset, report_name, **kwargs)
#     178     else:
#     179         # Update display names
#
# ~/Documents/pytracking/pytracking/analysis/extract_results.py in extract_results(trackers, dataset, report_name, skip_missing_seq, plot_bin_gap, exclude_invalid_frames)
#     141                     break
#     142                 else:
# --> 143                     raise Exception('Result not found. {}'.format(results_path))
#     144
#     145             # Calculate measures
#
# Exception: Result not found. /home/fyk/Documents/pytracking/pytracking/tracking_results//dimp/prdimp50/toy_car_low.txt
