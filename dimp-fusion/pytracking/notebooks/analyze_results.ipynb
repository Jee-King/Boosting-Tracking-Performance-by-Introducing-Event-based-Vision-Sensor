# %% [markdown]
# # Generating Results on Datasets

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import os
import sys
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [14, 8]

sys.path.append('../..')
from pytracking.analysis.plot_results import plot_results, print_results, print_per_sequence_results
from pytracking.evaluation import Tracker, get_dataset, trackerlist,  get_traindataset, get_valdataset

# %%
data_path = '/home/iccd/data/img_ext'
output_result = '/home/iccd/Document/Documents/pytracking_lstmsub/pytracking/tracking_results'
tracker_name = 'dimp'
test_case = 'prdimp18'
out_path = os.path.join(output_result,tracker_name,test_case)

# %% [markdown]
# ## Plots for OTB, NFS and UAV

# %%
trackers = []


# trackers.extend(trackerlist('dimp', 'prdimp18-e1', None, '1'))
# trackers.extend(trackerlist('dimp', 'prdimp18-e2', None, '2'))
# trackers.extend(trackerlist('dimp', 'prdimp18-e3', None, '3'))
# trackers.extend(trackerlist('dimp', 'prdimp18-e4', None, '4'))
# trackers.extend(trackerlist('dimp', 'prdimp18-e5', None, '5'))
# trackers.extend(trackerlist('dimp', 'prdimp18-e6', None, '6'))
# trackers.extend(trackerlist('dimp', 'prdimp18-e7', None, '7'))
# trackers.extend(trackerlist('dimp', 'prdimp18-e8', None, '8'))
# trackers.extend(trackerlist('dimp', 'prdimp18-e9', None, '9'))
# trackers.extend(trackerlist('dimp', 'prdimp18-e10', None, '10'))
# trackers.extend(trackerlist('dimp', 'prdimp18-e11', None, '11'))
# trackers.extend(trackerlist('dimp', 'prdimp18-e12', None, '12'))
# trackers.extend(trackerlist('dimp', 'prdimp18-e13', None, '13'))
# trackers.extend(trackerlist('dimp', 'prdimp18-e14', None, '14'))
trackers.extend(trackerlist('dimp', 'prdimp18-e15', None, '15'))

# trackers.extend(trackerlist('dimp', 'prdimp18-e16', None, '16'))
# trackers.extend(trackerlist('dimp', 'prdimp18-e17', None, '17'))
# trackers.extend(trackerlist('dimp', 'prdimp18-e18', None, '18'))
# trackers.extend(trackerlist('dimp', 'prdimp18-e19', None, '19'))
trackers.extend(trackerlist('dimp', 'prdimp18-e20', None, '20'))
trackers.extend(trackerlist('dimp', 'prdimp18-e21', None, '21'))
trackers.extend(trackerlist('dimp', 'prdimp18-e22', None, '22'))
trackers.extend(trackerlist('dimp', 'prdimp18-e23', None, '23'))
trackers.extend(trackerlist('dimp', 'prdimp18-e24', None, '24'))
trackers.extend(trackerlist('dimp', 'prdimp18-e25', None, '25'))
trackers.extend(trackerlist('dimp', 'prdimp18-e26', None, '26'))
trackers.extend(trackerlist('dimp', 'prdimp18-e27', None, '27'))
trackers.extend(trackerlist('dimp', 'prdimp18-e28', None, '28'))
trackers.extend(trackerlist('dimp', 'prdimp18-e29', None, '29'))
trackers.extend(trackerlist('dimp', 'prdimp18-e30', None, '30'))

# trackers.extend(trackerlist('dimp', 'prdimp18-e31', None, '31'))
# trackers.extend(trackerlist('dimp', 'prdimp18-e32', None, '32'))
# trackers.extend(trackerlist('dimp', 'prdimp18-e33', None, '33'))
# trackers.extend(trackerlist('dimp', 'prdimp18-e34', None, '34'))
# trackers.extend(trackerlist('dimp', 'prdimp18-e35', None, '35'))
# trackers.extend(trackerlist('dimp', 'prdimp18-e36', None, '36'))
# trackers.extend(trackerlist('dimp', 'prdimp18-e37', None, '37'))
# trackers.extend(trackerlist('dimp', 'prdimp18-e38', None, '38'))
# trackers.extend(trackerlist('dimp', 'prdimp18-e39', None, '39'))
# trackers.extend(trackerlist('dimp', 'prdimp18-e40', None, '40'))
# trackers.extend(trackerlist('dimp', 'prdimp18-e41', None, '41'))
# trackers.extend(trackerlist('dimp', 'prdimp18-e42', None, '42'))
# trackers.extend(trackerlist('dimp', 'prdimp18-e43', None, '43'))
# trackers.extend(trackerlist('dimp', 'prdimp18-e44', None, '44'))
# trackers.extend(trackerlist('dimp', 'prdimp18-e45', None, '45'))

# trackers.extend(trackerlist('dimp', 'prdimp18-e46', None, '46'))
# trackers.extend(trackerlist('dimp', 'prdimp18-e47', None, '47'))
# trackers.extend(trackerlist('dimp', 'prdimp18-e48', None, '48'))
# trackers.extend(trackerlist('dimp', 'prdimp18-e49', None, '49'))

# final model 
# trackers.extend(trackerlist('lstm-ablation', 'lstm+qkv+sub', None, 'lstm+qkv+sub'))

# ablation
##GM-lstm
# trackers.extend(trackerlist('lstm-ablation', 'lstm', None, 'lstm'))
# trackers.extend(trackerlist('lstm-ablation', 'lstm+mam', None, 'lstm+mam'))

##cdms
# trackers.extend(trackerlist('lstm-ablation', 'no-cdms', None, 'no-cdms'))
# trackers.extend(trackerlist('lstm-ablation', 'cdms-no-sa', None, 'cdms-no-sa'))
# trackers.extend(trackerlist('lstm-ablation', 'cdms-no-ca', None, 'cdms-no-ca'))
# trackers.extend(trackerlist('lstm-ablation', 'cdms-no-aw', None, 'cdms-no-aw'))
# trackers.extend(trackerlist('lstm-ablation', 'no-gmlstm', None, 'no-gmlstm'))
# trackers.extend(trackerlist('lstm-ablation', 'lstm-no-csde', None, 'lstm-no-csde'))

# trackers.extend(trackerlist('lstm-ablation', 'event-count', None, 'event-count'))
# trackers.extend(trackerlist('lstm-ablation', 'event-frame', None, 'event-frame'))
# trackers.extend(trackerlist('lstm-ablation', 'TS', None, 'TS'))
# trackers.extend(trackerlist('lstm-ablation', 'TSLTD', None, 'TSLTD'))
# trackers.extend(trackerlist('lstm-ablation', 'Zhu', None, 'Zhu'))

# sota
# trackers.extend(trackerlist('lstm-ablation', 'ICCV53.0', None, 'iccv21'))
# trackers.extend(trackerlist('lstm-ablation', 'only_event', None, 'only_event'))

# trackers.extend(trackerlist('sota', 'atom', None, 'ATOM'))
# trackers.extend(trackerlist('sota', 'prdimp50', None, 'PrDiMP50'))
# trackers.extend(trackerlist('sota', 'prdimp18', None, 'PrDiMP18'))

# trackers.extend(trackerlist('sota', 'dimp50', None, 'DiMP50'))
# trackers.extend(trackerlist('sota', 'kys', None, 'KYS'))
# trackers.extend(trackerlist('sota', 'default', None, 'K1'))
# trackers.extend(trackerlist('sota', 'checkpoint_e18', None, '18'))
# trackers.extend(trackerlist('sota', 'checkpoint_e19', None, '19'))
# trackers.extend(trackerlist('sota', 'checkpoint_e20', None, '20'))



# trackers.extend(trackerlist('dimp', 'prdimp18', None, 'prdimp18_epoch30'))

# trackers.extend(trackerlist('dimp', 'prdimp18_attenv2', None, 'prdimp18_attenv2'))

dataset = get_valdataset('eotb')
plot_results(trackers, dataset, 'EOTB', merge_results=True, plot_types=('success', 'prec'), 
             skip_missing_seq=True, force_evaluation=True, plot_bin_gap=0.05, exclude_invalid_frames=False)
# Out:
# 100%|██████████| 48/48 [00:04<00:00, 10.53it/s]
# Computed results over 48 / 48 sequences
#
# Plotting results over 48 / 48 sequences
#
# Generating plots for: EOTB

# %% [markdown]
# ## Plots for LaSOT

# %% [markdown]
# ## Tables for OTB, NFS, UAV and LaSOT

# %%
print_results(trackers, dataset, 'OTB', merge_results=True, plot_types=('success', 'prec', 'norm_prec'))
# Out:
# 100%|██████████| 48/48 [00:05<00:00,  8.47it/s]
# Computed results over 48 / 48 sequences
#
# Reporting results over 48 / 48 sequences
#
# OTB                    | AUC        | OP50       | OP75       | Precision    | Norm Precision    |
# dimp_prdimp18-e15      | 55.86      | 69.04      | 28.59      | 85.13        | 59.31             |
# dimp_prdimp18-e20      | 55.66      | 69.12      | 27.87      | 84.93        | 58.97             |
# dimp_prdimp18-e21      | 54.67      | 67.63      | 27.26      | 83.46        | 57.39             |
# dimp_prdimp18-e22      | 56.73      | 69.96      | 28.44      | 86.84        | 59.71             |
# dimp_prdimp18-e23      | 55.59      | 68.24      | 27.58      | 85.38        | 58.10             |
# dimp_prdimp18-e24      | 55.22      | 68.47      | 27.40      | 84.51        | 58.29             |
# dimp_prdimp18-e25      | 54.95      | 67.64      | 26.82      | 84.57        | 57.36             |
# ...

# %% [markdown]
# ## Filtered per-sequence results

# %%
# Print per sequence results for sequences where all trackers fail, i.e. all trackers have average overlap in percentage of less than 10.0
filter_criteria = {'mode': 'ao_max', 'threshold': 100.0}
dataset = get_valdataset('eotb')
print_per_sequence_results(trackers, dataset, 'EOTB', merge_results=True, filter_criteria=filter_criteria, force_evaluation=False)
# Out:
#                              | dimp_prdimp18-e13    | dimp_prdimp18-e16    | dimp_prdimp18-e17    | dimp_prdimp18-e18    |
# tower (ID=0)                 | 74.71                | 77.46                | 76.95                | 77.47                |
# giraffe222 (ID=1)            | 46.92                | 44.34                | 45.69                | 47.05                |
# bottle_mul222 (ID=2)         | 81.42                | 83.28                | 83.16                | 83.73                |
# ship_motion (ID=3)           | 59.65                | 61.46                | 60.82                | 61.57                |
# cup_low (ID=4)               | 73.65                | 72.80                | 73.17                | 71.50                |
# bike_low (ID=5)              | 66.71                | 70.97                | 72.84                | 68.19                |
# giraffe_motion (ID=6)        | 45.45                | 45.58                | 46.19                | 48.88                |
# ...

# %%
# Print per sequence results for sequences where at least one tracker fails, i.e. a tracker has average overlap in percentage of less than 10.0
filter_criteria = {'mode': 'ao_min', 'threshold': 99.0}
dataset = get_dataset('eotb')
print_per_sequence_results(trackers, dataset, 'OTB+NFS+UAV', merge_results=True, filter_criteria=filter_criteria, force_evaluation=False)
# Out:
#   0%|          | 0/124 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-9-fbc7d47e1bbe> in <module>
#       2 filter_criteria = {'mode': 'ao_min', 'threshold': 99.0}
#       3 dataset = get_dataset('eotb')
# ----> 4 print_per_sequence_results(trackers, dataset, 'OTB+NFS+UAV', merge_results=True, filter_criteria=filter_criteria, force_evaluation=False)
#
# ~/Document/Documents/pytracking/pytracking/analysis/plot_results.py in print_per_sequence_results(trackers, dataset, report_name, merge_results, filter_criteria, **kwargs)
#     447     """
#     448     # Load pre-computed results
# --> 449     eval_data = check_and_load_precomputed_results(trackers, dataset, report_name, **kwargs)
#     450
#     451     # Merge results from multiple runs
#
# ...

# %%
# Print per sequence results for sequences where the trackers have differing behavior.
# i.e. average overlap in percentage for different trackers on a sequence differ by at least 40.0
filter_criteria = {'mode': 'delta_ao', 'threshold': 40.0}
dataset = get_dataset('otb', 'nfs', 'uav')
print_per_sequence_results(trackers, dataset, 'OTB+NFS+UAV', merge_results=True, filter_criteria=filter_criteria, force_evaluation=False)

# %%
# Print per sequence results for all sequences
filter_criteria = None
dataset = get_dataset('eotb')
print_per_sequence_results(trackers, dataset, 'OTB+NFS+UAV', merge_results=False, filter_criteria=filter_criteria, force_evaluation=False)
# Out:
#   0%|          | 0/124 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-10-3d1244ede903> in <module>
#       2 filter_criteria = None
#       3 dataset = get_dataset('eotb')
# ----> 4 print_per_sequence_results(trackers, dataset, 'OTB+NFS+UAV', merge_results=False, filter_criteria=filter_criteria, force_evaluation=False)
#
# ~/Document/Documents/pytracking/pytracking/analysis/plot_results.py in print_per_sequence_results(trackers, dataset, report_name, merge_results, filter_criteria, **kwargs)
#     447     """
#     448     # Load pre-computed results
# --> 449     eval_data = check_and_load_precomputed_results(trackers, dataset, report_name, **kwargs)
#     450
#     451     # Merge results from multiple runs
#
# ...
